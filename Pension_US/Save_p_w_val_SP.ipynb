# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
from matplotlib import pyplot as plt
import pickle
import sys

sys.path.append('./../')

# %%
yyyy = np.load('./result/year/full_year.npy', allow_pickle=True).reshape(1)[0][35][0]
folder_name = 'dyna'

# %%
def model(retire_year, t, k) :
    retire = pd.read_csv('./w/SP100.csv')
    retire.drop(columns=retire.columns[0], axis=1, inplace=True)
    retire = retire[[str(year) for year in yyyy]]
    retire.columns = yyyy
    
    return  retire[retire_year][t]

# %%
# def model(retire_year, t, k) :
    
#     return  0.5

# %%
model_name = 'SP_100'

# %%
from Portfolio_value import cons_withdraw, dyna_withdraw

# %%
df =  pd.read_csv('./data/snp2.csv')

# %%
portfolio_strategy = [model]

# %%
# upper_year = 20
# k = 1.0
# withdraw_rate = 0.08

upper_years = [35]

# %% [markdown]
# # const

# %%
functions = [cons_withdraw]
init_p_val = 500000
k = 0
for upper_year in upper_years:
    for withdraw_rate in [0.05]:
        print('year{}_rate{}'.format(upper_year, withdraw_rate))
        p_val = {}
        w_val = {}
        years = yyyy
        for j, weight in enumerate(portfolio_strategy) :
            print('{} Strategy'.format(weight))

            for i, function in enumerate(functions) :
                for year in years :
                    print(year)
                    p_val[year] = function(year, weight, k, upper_year, withdraw_rate, df, init_p_val)[0]
                    w_val[year] = function(year, weight, k, upper_year, withdraw_rate, df, init_p_val)[1]

        p_val = pd.DataFrame(p_val)
        w_val = pd.DataFrame(w_val)
        p_val.to_csv('./result/{}/p_val/{}_rate{}_const.csv'.format(folder_name, model_name, withdraw_rate))
        w_val.to_csv('./result/{}/w_val/{}_rate{}_const.csv'.format(folder_name, model_name, withdraw_rate))
# Out:
# year35_rate0.05
# <function model at 0x7fd92d8b9040> Strategy
# 1928
# Mkt
# start_date:  1928-01-01 00:00:00
# end_date:  1963-01-01 00:00:00
# initial_weight:  0.5326520334646035
# Mkt
# start_date:  1928-01-01 00:00:00
# end_date:  1963-01-01 00:00:00
# initial_weight:  0.5326520334646035
# 1929
# Mkt
# start_date:  1929-01-01 00:00:00
# end_date:  1964-01-01 00:00:00
# initial_weight:  0.5320778204707939
# Mkt
# start_date:  1929-01-01 00:00:00
# end_date:  1964-01-01 00:00:00
# initial_weight:  0.5320778204707939
# 1930
# Mkt
# start_date:  1930-01-01 00:00:00
# end_date:  1965-01-01 00:00:00
# initial_weight:  0.5601546969520194
# Mkt
# start_date:  1930-01-01 00:00:00
# end_date:  1965-01-01 00:00:00
# initial_weight:  0.5601546969520194
# 1931
# Mkt
# start_date:  1931-01-01 00:00:00
# end_date:  1966-01-01 00:00:00
# initial_weight:  0.5516466242316329
# Mkt
# start_date:  1931-01-01 00:00:00
# end_date:  1966-01-01 00:00:00
# initial_weight:  0.5516466242316329
# 1932
# Mkt
# start_date:  1932-01-01 00:00:00
# end_date:  1967-01-01 00:00:00
# initial_weight:  0.5827371447583936
# Mkt
# start_date:  1932-01-01 00:00:00
# end_date:  1967-01-01 00:00:00
# initial_weight:  0.5827371447583936
# 1933
# Mkt
# start_date:  1933-01-01 00:00:00
# end_date:  1968-01-01 00:00:00
# initial_weight:  0.6239502007532423
# Mkt
# start_date:  1933-01-01 00:00:00
# end_date:  1968-01-01 00:00:00
# initial_weight:  0.6239502007532423
# 1934
# Mkt
# start_date:  1934-01-01 00:00:00
# end_date:  1969-01-01 00:00:00
# initial_weight:  0.6067354840347836
# Mkt
# start_date:  1934-01-01 00:00:00
# end_date:  1969-01-01 00:00:00
# initial_weight:  0.6067354840347836
# 1935
# Mkt
# start_date:  1935-01-01 00:00:00
# end_date:  1970-01-01 00:00:00
# initial_weight:  0.5359920136731817
# Mkt
# start_date:  1935-01-01 00:00:00
# end_date:  1970-01-01 00:00:00
# initial_weight:  0.5359920136731817
# 1936
# Mkt
# start_date:  1936-01-01 00:00:00
# end_date:  1971-01-01 00:00:00
# initial_weight:  0.5264731344003049
# Mkt
# start_date:  1936-01-01 00:00:00
# end_date:  1971-01-01 00:00:00
# initial_weight:  0.5264731344003049
# 1937
# Mkt
# start_date:  1937-01-01 00:00:00
# end_date:  1972-01-01 00:00:00
# initial_weight:  0.527492064220185
# Mkt
# start_date:  1937-01-01 00:00:00
# end_date:  1972-01-01 00:00:00
# initial_weight:  0.527492064220185
# 1938
# Mkt
# start_date:  1938-01-01 00:00:00
# end_date:  1973-01-01 00:00:00
# initial_weight:  0.5412795981229845
# Mkt
# start_date:  1938-01-01 00:00:00
# end_date:  1973-01-01 00:00:00
# initial_weight:  0.5412795981229845
# 1939
# Mkt
# start_date:  1939-01-01 00:00:00
# end_date:  1974-01-01 00:00:00
# initial_weight:  0.5808971158733846
# Mkt
# start_date:  1939-01-01 00:00:00
# end_date:  1974-01-01 00:00:00
# initial_weight:  0.5808971158733846
# 1940
# Mkt
# start_date:  1940-01-01 00:00:00
# end_date:  1975-01-01 00:00:00
# initial_weight:  0.5546788253843283
# Mkt
# start_date:  1940-01-01 00:00:00
# end_date:  1975-01-01 00:00:00
# initial_weight:  0.5546788253843283
# 1941
# Mkt
# start_date:  1941-01-01 00:00:00
# end_date:  1976-01-01 00:00:00
# initial_weight:  0.5503459853145426
# Mkt
# start_date:  1941-01-01 00:00:00
# end_date:  1976-01-01 00:00:00
# initial_weight:  0.5503459853145426
# 1942
# Mkt
# start_date:  1942-01-01 00:00:00
# end_date:  1977-01-01 00:00:00
# initial_weight:  0.5264076466027711
# Mkt
# start_date:  1942-01-01 00:00:00
# end_date:  1977-01-01 00:00:00
# initial_weight:  0.5264076466027711
# 1943
# Mkt
# start_date:  1943-01-01 00:00:00
# end_date:  1978-01-01 00:00:00
# initial_weight:  0.530871236697765
# Mkt
# start_date:  1943-01-01 00:00:00
# end_date:  1978-01-01 00:00:00
# initial_weight:  0.530871236697765
# 1944
# Mkt
# start_date:  1944-01-01 00:00:00
# end_date:  1979-01-01 00:00:00
# initial_weight:  0.5286541997279351
# Mkt
# start_date:  1944-01-01 00:00:00
# end_date:  1979-01-01 00:00:00
# initial_weight:  0.5286541997279351
# 1945
# Mkt
# start_date:  1945-01-01 00:00:00
# end_date:  1980-01-01 00:00:00
# initial_weight:  0.5164793392529967
# Mkt
# start_date:  1945-01-01 00:00:00
# end_date:  1980-01-01 00:00:00
# initial_weight:  0.5164793392529967
# 1946
# Mkt
# start_date:  1946-01-01 00:00:00
# end_date:  1981-01-01 00:00:00
# initial_weight:  0.5257427880266764
# Mkt
# start_date:  1946-01-01 00:00:00
# end_date:  1981-01-01 00:00:00
# initial_weight:  0.5257427880266764
# 1947
# Mkt
# start_date:  1947-01-01 00:00:00
# end_date:  1982-01-01 00:00:00
# initial_weight:  0.5356254531183562
# Mkt
# start_date:  1947-01-01 00:00:00
# end_date:  1982-01-01 00:00:00
# initial_weight:  0.5356254531183562
# 1948
# Mkt
# start_date:  1948-01-01 00:00:00
# end_date:  1983-01-01 00:00:00
# initial_weight:  0.5221958131149558
# Mkt
# start_date:  1948-01-01 00:00:00
# end_date:  1983-01-01 00:00:00
# initial_weight:  0.5221958131149558
# 1949
# Mkt
# start_date:  1949-01-01 00:00:00
# end_date:  1984-01-01 00:00:00
# initial_weight:  0.5372256662542872
# Mkt
# start_date:  1949-01-01 00:00:00
# end_date:  1984-01-01 00:00:00
# initial_weight:  0.5372256662542872
# 1950
# Mkt
# start_date:  1950-01-01 00:00:00
# end_date:  1985-01-01 00:00:00
# initial_weight:  0.5205986222680984
# Mkt
# start_date:  1950-01-01 00:00:00
# end_date:  1985-01-01 00:00:00
# initial_weight:  0.5205986222680984
# 1951
# Mkt
# start_date:  1951-01-01 00:00:00
# end_date:  1986-01-01 00:00:00
# initial_weight:  0.5229567375163455
# Mkt
# start_date:  1951-01-01 00:00:00
# end_date:  1986-01-01 00:00:00
# initial_weight:  0.5229567375163455
# 1952
# Mkt
# start_date:  1952-01-01 00:00:00
# end_date:  1987-01-01 00:00:00
# initial_weight:  0.5224955817634996
# Mkt
# start_date:  1952-01-01 00:00:00
# end_date:  1987-01-01 00:00:00
# initial_weight:  0.5224955817634996
# 1953
# Mkt
# start_date:  1953-01-01 00:00:00
# end_date:  1988-01-01 00:00:00
# initial_weight:  0.5229170044546556
# Mkt
# start_date:  1953-01-01 00:00:00
# end_date:  1988-01-01 00:00:00
# initial_weight:  0.5229170044546556
# 1954
# Mkt
# start_date:  1954-01-01 00:00:00
# end_date:  1989-01-01 00:00:00
# initial_weight:  0.5203385028955892
# Mkt
# start_date:  1954-01-01 00:00:00
# end_date:  1989-01-01 00:00:00
# initial_weight:  0.5203385028955892
# 1955
# Mkt
# start_date:  1955-01-01 00:00:00
# end_date:  1990-01-01 00:00:00
# initial_weight:  0.5236868177391978
# Mkt
# start_date:  1955-01-01 00:00:00
# end_date:  1990-01-01 00:00:00
# initial_weight:  0.5236868177391978
# 1956
# Mkt
# start_date:  1956-01-01 00:00:00
# end_date:  1991-01-01 00:00:00
# initial_weight:  0.5217861444313109
# Mkt
# start_date:  1956-01-01 00:00:00
# end_date:  1991-01-01 00:00:00
# initial_weight:  0.5217861444313109
# 1957
# Mkt
# start_date:  1957-01-01 00:00:00
# end_date:  1992-01-01 00:00:00
# initial_weight:  0.5280459944752298
# Mkt
# start_date:  1957-01-01 00:00:00
# end_date:  1992-01-01 00:00:00
# initial_weight:  0.5280459944752298
# 1958
# Mkt
# start_date:  1958-01-01 00:00:00
# end_date:  1993-01-01 00:00:00
# initial_weight:  0.5267785703670367
# Mkt
# start_date:  1958-01-01 00:00:00
# end_date:  1993-01-01 00:00:00
# initial_weight:  0.5267785703670367
# 1959
# Mkt
# start_date:  1959-01-01 00:00:00
# end_date:  1994-01-01 00:00:00
# initial_weight:  0.512933271545599
# Mkt
# start_date:  1959-01-01 00:00:00
# end_date:  1994-01-01 00:00:00
# initial_weight:  0.512933271545599
# 1960
# Mkt
# start_date:  1960-01-01 00:00:00
# end_date:  1995-01-01 00:00:00
# initial_weight:  0.5221948349729629
# Mkt
# start_date:  1960-01-01 00:00:00
# end_date:  1995-01-01 00:00:00
# initial_weight:  0.5221948349729629
# 1961
# Mkt
# start_date:  1961-01-01 00:00:00
# end_date:  1996-01-01 00:00:00
# initial_weight:  0.5250720303626466
# Mkt
# start_date:  1961-01-01 00:00:00
# end_date:  1996-01-01 00:00:00
# initial_weight:  0.5250720303626466
# 1962
# Mkt
# start_date:  1962-01-01 00:00:00
# end_date:  1997-01-01 00:00:00
# initial_weight:  0.5193889105846072
# Mkt
# start_date:  1962-01-01 00:00:00
# end_date:  1997-01-01 00:00:00
# initial_weight:  0.5193889105846072
# 1963
# Mkt
# start_date:  1963-01-01 00:00:00
# end_date:  1998-01-01 00:00:00
# initial_weight:  0.5423501568072446
# Mkt
# start_date:  1963-01-01 00:00:00
# end_date:  1998-01-01 00:00:00
# initial_weight:  0.5423501568072446
# 1964
# Mkt
# start_date:  1964-01-01 00:00:00
# end_date:  1999-01-01 00:00:00
# initial_weight:  0.5179158333350884
# Mkt
# start_date:  1964-01-01 00:00:00
# end_date:  1999-01-01 00:00:00
# initial_weight:  0.5179158333350884
# 1965
# Mkt
# start_date:  1965-01-01 00:00:00
# end_date:  2000-01-01 00:00:00
# initial_weight:  0.509655909212955
# Mkt
# start_date:  1965-01-01 00:00:00
# end_date:  2000-01-01 00:00:00
# initial_weight:  0.509655909212955
# 1966
# Mkt
# start_date:  1966-01-01 00:00:00
# end_date:  2001-01-01 00:00:00
# initial_weight:  0.5170629379177251
# Mkt
# start_date:  1966-01-01 00:00:00
# end_date:  2001-01-01 00:00:00
# initial_weight:  0.5170629379177251
# 1967
# Mkt
# start_date:  1967-01-01 00:00:00
# end_date:  2002-01-01 00:00:00
# initial_weight:  0.5293875597337526
# Mkt
# start_date:  1967-01-01 00:00:00
# end_date:  2002-01-01 00:00:00
# initial_weight:  0.5293875597337526
# 1968
# Mkt
# start_date:  1968-01-01 00:00:00
# end_date:  2003-01-01 00:00:00
# initial_weight:  0.5226426324109522
# Mkt
# start_date:  1968-01-01 00:00:00
# end_date:  2003-01-01 00:00:00
# initial_weight:  0.5226426324109522
# 1969
# Mkt
# start_date:  1969-01-01 00:00:00
# end_date:  2004-01-01 00:00:00
# initial_weight:  0.5269204766556952
# Mkt
# start_date:  1969-01-01 00:00:00
# end_date:  2004-01-01 00:00:00
# initial_weight:  0.5269204766556952
# 1970
# Mkt
# start_date:  1970-01-01 00:00:00
# end_date:  2005-01-01 00:00:00
# initial_weight:  0.5326153582570312
# Mkt
# start_date:  1970-01-01 00:00:00
# end_date:  2005-01-01 00:00:00
# initial_weight:  0.5326153582570312
# 1971
# Mkt
# start_date:  1971-01-01 00:00:00
# end_date:  2006-01-01 00:00:00
# initial_weight:  0.5414039352656542
# Mkt
# start_date:  1971-01-01 00:00:00
# end_date:  2006-01-01 00:00:00
# initial_weight:  0.5414039352656542
# 1972
# Mkt
# start_date:  1972-01-01 00:00:00
# end_date:  2007-01-01 00:00:00
# initial_weight:  0.5278570689970885
# Mkt
# start_date:  1972-01-01 00:00:00
# end_date:  2007-01-01 00:00:00
# initial_weight:  0.5278570689970885
# 1973
# Mkt
# start_date:  1973-01-01 00:00:00
# end_date:  2008-01-01 00:00:00
# initial_weight:  0.5162380161627905
# Mkt
# start_date:  1973-01-01 00:00:00
# end_date:  2008-01-01 00:00:00
# initial_weight:  0.5162380161627905
# 1974
# Mkt
# start_date:  1974-01-01 00:00:00
# end_date:  2009-01-01 00:00:00
# initial_weight:  0.5335324633063193
# Mkt
# start_date:  1974-01-01 00:00:00
# end_date:  2009-01-01 00:00:00
# initial_weight:  0.5335324633063193
# 1975
# Mkt
# start_date:  1975-01-01 00:00:00
# end_date:  2010-01-01 00:00:00
# initial_weight:  0.5582601546537659
# Mkt
# start_date:  1975-01-01 00:00:00
# end_date:  2010-01-01 00:00:00
# initial_weight:  0.5582601546537659
# 1976
# Mkt
# start_date:  1976-01-01 00:00:00
# end_date:  2011-01-01 00:00:00
# initial_weight:  0.536286721167321
# Mkt
# start_date:  1976-01-01 00:00:00
# end_date:  2011-01-01 00:00:00
# initial_weight:  0.536286721167321
# 1977
# Mkt
# start_date:  1977-01-01 00:00:00
# end_date:  2012-01-01 00:00:00
# initial_weight:  0.5196431644749846
# Mkt
# start_date:  1977-01-01 00:00:00
# end_date:  2012-01-01 00:00:00
# initial_weight:  0.5196431644749846
# 1978
# Mkt
# start_date:  1978-01-01 00:00:00
# end_date:  2013-01-01 00:00:00
# initial_weight:  0.5211892070421902
# Mkt
# start_date:  1978-01-01 00:00:00
# end_date:  2013-01-01 00:00:00
# initial_weight:  0.5211892070421902
# 1979
# Mkt
# start_date:  1979-01-01 00:00:00
# end_date:  2014-01-01 00:00:00
# initial_weight:  0.5348399456476146
# Mkt
# start_date:  1979-01-01 00:00:00
# end_date:  2014-01-01 00:00:00
# initial_weight:  0.5348399456476146
# 1980
# Mkt
# start_date:  1980-01-01 00:00:00
# end_date:  2015-01-01 00:00:00
# initial_weight:  0.5305165920096522
# Mkt
# start_date:  1980-01-01 00:00:00
# end_date:  2015-01-01 00:00:00
# initial_weight:  0.5305165920096522
# 1981
# Mkt
# start_date:  1981-01-01 00:00:00
# end_date:  2016-01-01 00:00:00
# initial_weight:  0.5412418023426679
# Mkt
# start_date:  1981-01-01 00:00:00
# end_date:  2016-01-01 00:00:00
# initial_weight:  0.5412418023426679
# 1982
# Mkt
# start_date:  1982-01-01 00:00:00
# end_date:  2017-01-01 00:00:00
# initial_weight:  0.5275169865774033
# Mkt
# start_date:  1982-01-01 00:00:00
# end_date:  2017-01-01 00:00:00
# initial_weight:  0.5275169865774033
# 1983
# Mkt
# start_date:  1983-01-01 00:00:00
# end_date:  2018-01-01 00:00:00
# initial_weight:  0.5383318405031771
# Mkt
# start_date:  1983-01-01 00:00:00
# end_date:  2018-01-01 00:00:00
# initial_weight:  0.5383318405031771

# %% [markdown]
# # dynamic

# %%
functions = [dyna_withdraw]
init_p_val = 500000
k = 0

for upper_year in upper_years:
    for withdraw_rate in [0.07]:
        print('year{}_rate{}'.format(upper_year, withdraw_rate))
        p_val = {}
        w_val = {}
        years = yyyy
        for j, weight in enumerate(portfolio_strategy) :
            print('{} Strategy'.format(weight))

            for i, function in enumerate(functions) :
                for year in years :
                    print(year)
                    p_val[year] = function(year, weight, k, upper_year, withdraw_rate, df, init_p_val)[0]
                    w_val[year] = function(year, weight, k, upper_year, withdraw_rate, df, init_p_val)[1]

        p_val = pd.DataFrame(p_val)
        w_val = pd.DataFrame(w_val)
        p_val.to_csv('./result/{}/p_val/{}_rate{}_dyna.csv'.format(folder_name, model_name, withdraw_rate))
        w_val.to_csv('./result/{}/w_val/{}_rate{}_dyna.csv'.format(folder_name, model_name, withdraw_rate))
# Out:
# year35_rate0.07
# <function model at 0x7fabf4b76670> Strategy
# 1928
# 1929
# 1930
# 1931
# 1932
# 1933
# 1934
# 1935
# 1936
# 1937
# 1938
# 1939
# 1940
# 1941
# 1942
# 1943
# 1944
# 1945
# 1946
# 1947
# 1948
# 1949
# 1950
# 1951
# 1952
# 1953
# 1954
# 1955
# 1956
# 1957
# 1958
# 1959
# 1960
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980
# 1981
# 1982
# 1983
