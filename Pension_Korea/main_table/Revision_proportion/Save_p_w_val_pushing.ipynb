# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
from matplotlib import pyplot as plt
import pickle
import sys

sys.path.append('./../../')

# %%
def static(year,t,k) :
    return k

# %%
from Portfolio_value import cons_withdraw, dyna_withdraw

# %%
df =  pd.read_csv('./../../data/data.csv')

# %%
portfolio_strategy = [static]

# %%
# upper_year = 20
# k = 1.0
# withdraw_rate = 0.08

upper_years =[10, 15, 20, 25, 30]

# %%
# 8 -> 5.1 / 4.7 / 4.3
# 6 -> 3 / 2.6 / 2.1
# 4 -> 1.3 / 0.9 / 0.5

# %% [markdown]
# # const

# %%
functions = [cons_withdraw]
init_p_val = 350000

for upper_year in upper_years:
    for k in [0.2,0.3,0.4]:
        for withdraw_rate in [0.021, 0.026, 0.03, 0.043, 0.047, 0.051]:
            print('year{}_k{}_rate{}'.format(upper_year, k, withdraw_rate))
            p_val = {}
            w_val = {}
            years = list(np.arange(1980,2023-upper_year))
            for j, weight in enumerate(portfolio_strategy) :
                print('{} Strategy'.format(weight))

                for i, function in enumerate(functions) :
                    for year in years :
                        print(year)
                        p_val[year] = function(year, weight, k, upper_year, withdraw_rate, df, init_p_val)[0]
                        w_val[year] = function(year, weight, k, upper_year, withdraw_rate, df, init_p_val)[1]
           
            p_val = pd.DataFrame(p_val)
            w_val = pd.DataFrame(w_val)
            p_val.to_csv('./../../result/revision/revision_proportion/p_val/year{}_k{}_rate{}_const_delaying.csv'.format(upper_year, k, withdraw_rate))
            w_val.to_csv('./../../result/revision/revision_proportion/w_val/year{}_k{}_rate{}_const_delaying.csv'.format(upper_year, k, withdraw_rate))
# Out:
# year10_k0.2_rate0.021
# <function static at 0x7f1e7820b670> Strategy
# 1980
# start_date:  1980-01-01 00:00:00
# end_date:  1990-01-01 00:00:00
# initial_weight:  0.2
# start_date:  1980-01-01 00:00:00
# end_date:  1990-01-01 00:00:00
# initial_weight:  0.2
# 1981
# start_date:  1981-01-01 00:00:00
# end_date:  1991-01-01 00:00:00
# initial_weight:  0.2
# start_date:  1981-01-01 00:00:00
# end_date:  1991-01-01 00:00:00
# initial_weight:  0.2
# 1982
# start_date:  1982-01-01 00:00:00
# end_date:  1992-01-01 00:00:00
# initial_weight:  0.2
# start_date:  1982-01-01 00:00:00
# end_date:  1992-01-01 00:00:00
# initial_weight:  0.2
# 1983
# start_date:  1983-01-01 00:00:00
# end_date:  1993-01-01 00:00:00
# initial_weight:  0.2
# start_date:  1983-01-01 00:00:00
# end_date:  1993-01-01 00:00:00
# initial_weight:  0.2
# 1984
# start_date:  1984-01-01 00:00:00
# end_date:  1994-01-01 00:00:00
# initial_weight:  0.2
# start_date:  1984-01-01 00:00:00
# end_date:  1994-01-01 00:00:00
# ...

# %%
p_val = {}
w_val = {}
for upper_year in upper_years:
    for k in [0.2,0.3,0.4]:
        for withdraw_rate in [0.021, 0.026, 0.03, 0.043, 0.047, 0.051]:
            p_val['year{}_k{}_rate{}'.format(upper_year, k, withdraw_rate)] = {}
            w_val['year{}_k{}_rate{}'.format(upper_year, k, withdraw_rate)] = {}

# %%
for upper_year in upper_years:
    for k in [0.2,0.3,0.4]:
        for withdraw_rate in [0.021, 0.026, 0.03, 0.043, 0.047, 0.051]:
            for year in range(1980,2023-upper_year):
                print('year{}_k{}_rate{}'.format(upper_year, k, withdraw_rate))
                print(year)
                p_val['year{}_k{}_rate{}'.format(upper_year, k, withdraw_rate)][year] = np.array(pd.read_csv('./../../result/revision/revision_proportion/p_val/year{}_k{}_rate{}_const_delaying.csv'.format(upper_year, k, withdraw_rate))[str(year)])
                w_val['year{}_k{}_rate{}'.format(upper_year, k, withdraw_rate)][year] = np.array(pd.read_csv('./../../result/revision/revision_proportion/w_val/year{}_k{}_rate{}_const_delaying.csv'.format(upper_year, k, withdraw_rate))[str(year)])

np.save('./../../result/revision/revision_proportion/p_val/p_val_const_delaying.npy', p_val)
np.save('./../../result/revision/revision_proportion/w_val/w_val_const_delaying.npy', w_val)
# Out:
# year10_k0.2_rate0.021
# 1980
# year10_k0.2_rate0.021
# 1981
# year10_k0.2_rate0.021
# 1982
# year10_k0.2_rate0.021
# 1983
# year10_k0.2_rate0.021
# 1984
# year10_k0.2_rate0.021
# 1985
# year10_k0.2_rate0.021
# 1986
# year10_k0.2_rate0.021
# 1987
# year10_k0.2_rate0.021
# 1988
# year10_k0.2_rate0.021
# 1989
# year10_k0.2_rate0.021
# 1990
# year10_k0.2_rate0.021
# 1991
# year10_k0.2_rate0.021
# 1992
# year10_k0.2_rate0.021
# 1993
# year10_k0.2_rate0.021
# 1994
# year10_k0.2_rate0.021
# 1995
# year10_k0.2_rate0.021
# 1996
# year10_k0.2_rate0.021
# 1997
# year10_k0.2_rate0.021
# 1998
# year10_k0.2_rate0.021
# 1999
# year10_k0.2_rate0.021
# 2000
# year10_k0.2_rate0.021
# 2001
# year10_k0.2_rate0.021
# 2002
# year10_k0.2_rate0.021
# 2003
# year10_k0.2_rate0.021
# 2004
# year10_k0.2_rate0.021
# 2005
# year10_k0.2_rate0.021
# 2006
# year10_k0.2_rate0.021
# 2007
# year10_k0.2_rate0.021
# 2008
# year10_k0.2_rate0.021
# 2009
# year10_k0.2_rate0.021
# 2010
# year10_k0.2_rate0.021
# 2011
# ...
