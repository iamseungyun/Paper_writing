# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
from matplotlib import pyplot as plt
import pickle
import import_ipynb
import os

# %%
def static(year,t,k) :
    return 0.5

# %%
def cons_withdraw(retire_year, weight, k, years, withdraw_rate, df, portfolio_value) :
    start_date = datetime(retire_year, 1, 1)
    print('start_date: ',start_date)
    end_date = start_date + relativedelta(years=years)
    print('end_date: ',end_date)
    
    annual_withdraw = portfolio_value*withdraw_rate
    initial_weight = weight(retire_year, 0, k)
    print('initial_weight: ',initial_weight)
    
    df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m')
    df = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]
    
    portfolio_values = []
    withdraw_amounts = []
    
    for i in range(df.shape[0]-1) :
        if i%12 == 0 :
            portfolio_value -= annual_withdraw*((0.99)**(i/12))*(df.iloc[i]['CPI']/df.iloc[0]['CPI'])
        
            withdraw_amounts.append(annual_withdraw*((0.99)**(i/12)))
        
        if i > 0 :
            stock_value = portfolio_value*weight(retire_year, i-1, k)*(1+df.iloc[i]['Mkt'])
            bond_value = portfolio_value*(1-weight(retire_year, i-1, k))*(1+df.iloc[i]['RF'])
        else :
            stock_value = portfolio_value*initial_weight
            bond_value = portfolio_value*(1-initial_weight)
            
        portfolio_value = stock_value + bond_value
        
        if portfolio_value < 0 :
            portfolio_value = 0
            annual_withdraw = 0
            
        portfolio_values.append(portfolio_value*(df.iloc[0]['CPI']/df.iloc[i]['CPI']))
    
    stock_value = portfolio_value*weight(retire_year, 12*years-1, k)*(1+df.iloc[12*years]['Mkt'])
    bond_value = portfolio_value*(1-weight(retire_year, 12*years-1, k))*(1+df.iloc[12*years]['RF'])
    portfolio_value = stock_value + bond_value
    portfolio_values.append(portfolio_value*(df.iloc[0]['CPI']/df.iloc[12*years]['CPI']))
        
        
    portfolio_values = np.array(portfolio_values)
    portfolio_values = portfolio_values/portfolio_values[0]*100
    withdraw_amounts = np.array(withdraw_amounts)
        
    return portfolio_values, withdraw_amounts

# %%
dt = pd.read_csv('./data/data.csv')

# %%
path = os.getcwd() + '/result/income_rate/'

# %% [markdown]
# # Dimension 1

# %%
dic ={}
dic2 = {}

for year in range(1980, 1993) :
    dic[year] = [0 for i in range(361)]
    dic2[year] = [0 for i in range(30)]
    
dic_2 ={}
dic2_2 = {}

for year in range(1980, 2003) :
    dic_2[year] = [0 for i in range(241)]
    dic2_2[year] = [0 for i in range(20)]
    
dic_3 ={}
dic2_3 = {}

for year in range(1980, 1998) :
    dic_3[year] = [0 for i in range(301)]
    dic2_3[year] = [0 for i in range(25)]

# %%
p_val_30_10_m = pd.DataFrame(dic)
p_val_30_20_m = pd.DataFrame(dic)
p_val_30_30_m = pd.DataFrame(dic)
p_val_30_40_m = pd.DataFrame(dic)
p_val_30_50_m = pd.DataFrame(dic)
p_val_30_60_m = pd.DataFrame(dic)
p_val_30_70_m = pd.DataFrame(dic)
p_val_30_80_m = pd.DataFrame(dic)
p_val_30_90_m = pd.DataFrame(dic)

p_val_20_10_m = pd.DataFrame(dic_2)
p_val_20_20_m = pd.DataFrame(dic_2)
p_val_20_30_m = pd.DataFrame(dic_2)
p_val_20_40_m = pd.DataFrame(dic_2)
p_val_20_50_m = pd.DataFrame(dic_2)
p_val_20_60_m = pd.DataFrame(dic_2)
p_val_20_70_m = pd.DataFrame(dic_2)
p_val_20_80_m = pd.DataFrame(dic_2)
p_val_20_90_m = pd.DataFrame(dic_2)

p_val_25_10_m = pd.DataFrame(dic_3)
p_val_25_20_m = pd.DataFrame(dic_3)
p_val_25_30_m = pd.DataFrame(dic_3)
p_val_25_40_m = pd.DataFrame(dic_3)
p_val_25_50_m = pd.DataFrame(dic_3)
p_val_25_60_m = pd.DataFrame(dic_3)
p_val_25_70_m = pd.DataFrame(dic_3)
p_val_25_80_m = pd.DataFrame(dic_3)
p_val_25_90_m = pd.DataFrame(dic_3)

p_val_30_10_p = pd.DataFrame(dic)
p_val_30_20_p = pd.DataFrame(dic)
p_val_30_30_p = pd.DataFrame(dic)
p_val_30_40_p = pd.DataFrame(dic)
p_val_30_50_p = pd.DataFrame(dic)
p_val_30_60_p = pd.DataFrame(dic)
p_val_30_70_p = pd.DataFrame(dic)
p_val_30_80_p = pd.DataFrame(dic)
p_val_30_90_p = pd.DataFrame(dic)

p_val_20_10_p = pd.DataFrame(dic_2)
p_val_20_20_p = pd.DataFrame(dic_2)
p_val_20_30_p = pd.DataFrame(dic_2)
p_val_20_40_p = pd.DataFrame(dic_2)
p_val_20_50_p = pd.DataFrame(dic_2)
p_val_20_60_p = pd.DataFrame(dic_2)
p_val_20_70_p = pd.DataFrame(dic_2)
p_val_20_80_p = pd.DataFrame(dic_2)
p_val_20_90_p = pd.DataFrame(dic_2)

p_val_25_10_p = pd.DataFrame(dic_3)
p_val_25_20_p = pd.DataFrame(dic_3)
p_val_25_30_p = pd.DataFrame(dic_3)
p_val_25_40_p = pd.DataFrame(dic_3)
p_val_25_50_p = pd.DataFrame(dic_3)
p_val_25_60_p = pd.DataFrame(dic_3)
p_val_25_70_p = pd.DataFrame(dic_3)
p_val_25_80_p = pd.DataFrame(dic_3)
p_val_25_90_p = pd.DataFrame(dic_3)

# %%
w_val_30_10_m = pd.DataFrame(dic2)
w_val_30_20_m = pd.DataFrame(dic2)
w_val_30_30_m = pd.DataFrame(dic2)
w_val_30_40_m = pd.DataFrame(dic2)
w_val_30_50_m = pd.DataFrame(dic2)
w_val_30_60_m = pd.DataFrame(dic2)
w_val_30_70_m = pd.DataFrame(dic2)
w_val_30_80_m = pd.DataFrame(dic2)
w_val_30_90_m = pd.DataFrame(dic2)

w_val_20_10_m = pd.DataFrame(dic2_2)
w_val_20_20_m = pd.DataFrame(dic2_2)
w_val_20_30_m = pd.DataFrame(dic2_2)
w_val_20_40_m = pd.DataFrame(dic2_2)
w_val_20_50_m = pd.DataFrame(dic2_2)
w_val_20_60_m = pd.DataFrame(dic2_2)
w_val_20_70_m = pd.DataFrame(dic2_2)
w_val_20_80_m = pd.DataFrame(dic2_2)
w_val_20_90_m = pd.DataFrame(dic2_2)

w_val_25_10_m = pd.DataFrame(dic2_3)
w_val_25_20_m = pd.DataFrame(dic2_3)
w_val_25_30_m = pd.DataFrame(dic2_3)
w_val_25_40_m = pd.DataFrame(dic2_3)
w_val_25_50_m = pd.DataFrame(dic2_3)
w_val_25_60_m = pd.DataFrame(dic2_3)
w_val_25_70_m = pd.DataFrame(dic2_3)
w_val_25_80_m = pd.DataFrame(dic2_3)
w_val_25_90_m = pd.DataFrame(dic2_3)

w_val_30_10_p = pd.DataFrame(dic2)
w_val_30_20_p = pd.DataFrame(dic2)
w_val_30_30_p = pd.DataFrame(dic2)
w_val_30_40_p = pd.DataFrame(dic2)
w_val_30_50_p = pd.DataFrame(dic2)
w_val_30_60_p = pd.DataFrame(dic2)
w_val_30_70_p = pd.DataFrame(dic2)
w_val_30_80_p = pd.DataFrame(dic2)
w_val_30_90_p = pd.DataFrame(dic2)

w_val_20_10_p = pd.DataFrame(dic2_2)
w_val_20_20_p = pd.DataFrame(dic2_2)
w_val_20_30_p = pd.DataFrame(dic2_2)
w_val_20_40_p = pd.DataFrame(dic2_2)
w_val_20_50_p = pd.DataFrame(dic2_2)
w_val_20_60_p = pd.DataFrame(dic2_2)
w_val_20_70_p = pd.DataFrame(dic2_2)
w_val_20_80_p = pd.DataFrame(dic2_2)
w_val_20_90_p = pd.DataFrame(dic2_2)

w_val_25_10_p = pd.DataFrame(dic2_3)
w_val_25_20_p = pd.DataFrame(dic2_3)
w_val_25_30_p = pd.DataFrame(dic2_3)
w_val_25_40_p = pd.DataFrame(dic2_3)
w_val_25_50_p = pd.DataFrame(dic2_3)
w_val_25_60_p = pd.DataFrame(dic2_3)
w_val_25_70_p = pd.DataFrame(dic2_3)
w_val_25_80_p = pd.DataFrame(dic2_3)
w_val_25_90_p = pd.DataFrame(dic2_3)

# %%
for year in range(1980, 1993) :
    p_val_30_10_m[year] = cons_withdraw(year, static, 0.5, 30, 0.044, dt, 350000)[0]
    p_val_30_20_m[year] = cons_withdraw(year, static, 0.5, 30, 0.042, dt, 350000)[0]
    p_val_30_30_m[year] = cons_withdraw(year, static, 0.5, 30, 0.04, dt, 350000)[0]
    p_val_30_40_m[year] = cons_withdraw(year, static, 0.5, 30, 0.039, dt, 350000)[0]
    p_val_30_50_m[year] = cons_withdraw(year, static, 0.5, 30, 0.037, dt, 350000)[0]
    p_val_30_60_m[year] = cons_withdraw(year, static, 0.5, 30, 0.036, dt, 350000)[0]
    p_val_30_70_m[year] = cons_withdraw(year, static, 0.5, 30, 0.034, dt, 350000)[0]
    p_val_30_80_m[year] = cons_withdraw(year, static, 0.5, 30, 0.031, dt, 350000)[0]
    p_val_30_90_m[year] = cons_withdraw(year, static, 0.5, 30, 0.026, dt, 350000)[0]

    p_val_30_10_p[year] = cons_withdraw(year, static, 0.5, 30, 0.064, dt, 350000)[0]
    p_val_30_20_p[year] = cons_withdraw(year, static, 0.5, 30, 0.062, dt, 350000)[0]
    p_val_30_30_p[year] = cons_withdraw(year, static, 0.5, 30, 0.06, dt, 350000)[0]
    p_val_30_40_p[year] = cons_withdraw(year, static, 0.5, 30, 0.059, dt, 350000)[0]
    p_val_30_50_p[year] = cons_withdraw(year, static, 0.5, 30, 0.057, dt, 350000)[0]
    p_val_30_60_p[year] = cons_withdraw(year, static, 0.5, 30, 0.056, dt, 350000)[0]
    p_val_30_70_p[year] = cons_withdraw(year, static, 0.5, 30, 0.054, dt, 350000)[0]
    p_val_30_80_p[year] = cons_withdraw(year, static, 0.5, 30, 0.051, dt, 350000)[0]
    p_val_30_90_p[year] = cons_withdraw(year, static, 0.5, 30, 0.046, dt, 350000)[0]

    w_val_30_10_m[year] = cons_withdraw(year, static, 0.5, 30, 0.044, dt, 350000)[1]
    w_val_30_20_m[year] = cons_withdraw(year, static, 0.5, 30, 0.042, dt, 350000)[1]
    w_val_30_30_m[year] = cons_withdraw(year, static, 0.5, 30, 0.04, dt, 350000)[1]
    w_val_30_40_m[year] = cons_withdraw(year, static, 0.5, 30, 0.039, dt, 350000)[1]
    w_val_30_50_m[year] = cons_withdraw(year, static, 0.5, 30, 0.037, dt, 350000)[1]
    w_val_30_60_m[year] = cons_withdraw(year, static, 0.5, 30, 0.036, dt, 350000)[1]
    w_val_30_70_m[year] = cons_withdraw(year, static, 0.5, 30, 0.034, dt, 350000)[1]
    w_val_30_80_m[year] = cons_withdraw(year, static, 0.5, 30, 0.031, dt, 350000)[1]
    w_val_30_90_m[year] = cons_withdraw(year, static, 0.5, 30, 0.026, dt, 350000)[1]

    w_val_30_10_p[year] = cons_withdraw(year, static, 0.5, 30, 0.064, dt, 350000)[1]
    w_val_30_20_p[year] = cons_withdraw(year, static, 0.5, 30, 0.062, dt, 350000)[1]
    w_val_30_30_p[year] = cons_withdraw(year, static, 0.5, 30, 0.06, dt, 350000)[1]
    w_val_30_40_p[year] = cons_withdraw(year, static, 0.5, 30, 0.059, dt, 350000)[1]
    w_val_30_50_p[year] = cons_withdraw(year, static, 0.5, 30, 0.057, dt, 350000)[1]
    w_val_30_60_p[year] = cons_withdraw(year, static, 0.5, 30, 0.056, dt, 350000)[1]
    w_val_30_70_p[year] = cons_withdraw(year, static, 0.5, 30, 0.054, dt, 350000)[1]
    w_val_30_80_p[year] = cons_withdraw(year, static, 0.5, 30, 0.051, dt, 350000)[1]
    w_val_30_90_p[year] = cons_withdraw(year, static, 0.5, 30, 0.046, dt, 350000)[1]
# Out:
# start_date:  1980-01-01 00:00:00
# end_date:  2010-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2010-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2010-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2010-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2010-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2010-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2010-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2010-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2010-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2010-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2010-01-01 00:00:00
# ...

# %%
for year in range(1980, 2003) :
    p_val_20_10_m[year] = cons_withdraw(year, static, 0.5, 20, 0.044, dt, 350000)[0]
    p_val_20_20_m[year] = cons_withdraw(year, static, 0.5, 20, 0.042, dt, 350000)[0]
    p_val_20_30_m[year] = cons_withdraw(year, static, 0.5, 20, 0.04, dt, 350000)[0]
    p_val_20_40_m[year] = cons_withdraw(year, static, 0.5, 20, 0.039, dt, 350000)[0]
    p_val_20_50_m[year] = cons_withdraw(year, static, 0.5, 20, 0.037, dt, 350000)[0]
    p_val_20_60_m[year] = cons_withdraw(year, static, 0.5, 20, 0.036, dt, 350000)[0]
    p_val_20_70_m[year] = cons_withdraw(year, static, 0.5, 20, 0.034, dt, 350000)[0]
    p_val_20_80_m[year] = cons_withdraw(year, static, 0.5, 20, 0.031, dt, 350000)[0]
    p_val_20_90_m[year] = cons_withdraw(year, static, 0.5, 20, 0.026, dt, 350000)[0]
    
    p_val_20_10_p[year] = cons_withdraw(year, static, 0.5, 20, 0.064, dt, 350000)[0]
    p_val_20_20_p[year] = cons_withdraw(year, static, 0.5, 20, 0.062, dt, 350000)[0]
    p_val_20_30_p[year] = cons_withdraw(year, static, 0.5, 20, 0.06, dt, 350000)[0]
    p_val_20_40_p[year] = cons_withdraw(year, static, 0.5, 20, 0.059, dt, 350000)[0]
    p_val_20_50_p[year] = cons_withdraw(year, static, 0.5, 20, 0.057, dt, 350000)[0]
    p_val_20_60_p[year] = cons_withdraw(year, static, 0.5, 20, 0.056, dt, 350000)[0]
    p_val_20_70_p[year] = cons_withdraw(year, static, 0.5, 20, 0.054, dt, 350000)[0]
    p_val_20_80_p[year] = cons_withdraw(year, static, 0.5, 20, 0.051, dt, 350000)[0]
    p_val_20_90_p[year] = cons_withdraw(year, static, 0.5, 20, 0.046, dt, 350000)[0]
    
    w_val_20_10_m[year] = cons_withdraw(year, static, 0.5, 20, 0.044, dt, 350000)[1]
    w_val_20_20_m[year] = cons_withdraw(year, static, 0.5, 20, 0.042, dt, 350000)[1]
    w_val_20_30_m[year] = cons_withdraw(year, static, 0.5, 20, 0.04, dt, 350000)[1]
    w_val_20_40_m[year] = cons_withdraw(year, static, 0.5, 20, 0.039, dt, 350000)[1]
    w_val_20_50_m[year] = cons_withdraw(year, static, 0.5, 20, 0.037, dt, 350000)[1]
    w_val_20_60_m[year] = cons_withdraw(year, static, 0.5, 20, 0.036, dt, 350000)[1]
    w_val_20_70_m[year] = cons_withdraw(year, static, 0.5, 20, 0.034, dt, 350000)[1]
    w_val_20_80_m[year] = cons_withdraw(year, static, 0.5, 20, 0.031, dt, 350000)[1]
    w_val_20_90_m[year] = cons_withdraw(year, static, 0.5, 20, 0.026, dt, 350000)[1]
    
    w_val_20_10_p[year] = cons_withdraw(year, static, 0.5, 20, 0.064, dt, 350000)[1]
    w_val_20_20_p[year] = cons_withdraw(year, static, 0.5, 20, 0.062, dt, 350000)[1]
    w_val_20_30_p[year] = cons_withdraw(year, static, 0.5, 20, 0.06, dt, 350000)[1]
    w_val_20_40_p[year] = cons_withdraw(year, static, 0.5, 20, 0.059, dt, 350000)[1]
    w_val_20_50_p[year] = cons_withdraw(year, static, 0.5, 20, 0.057, dt, 350000)[1]
    w_val_20_60_p[year] = cons_withdraw(year, static, 0.5, 20, 0.056, dt, 350000)[1]
    w_val_20_70_p[year] = cons_withdraw(year, static, 0.5, 20, 0.054, dt, 350000)[1]
    w_val_20_80_p[year] = cons_withdraw(year, static, 0.5, 20, 0.051, dt, 350000)[1]
    w_val_20_90_p[year] = cons_withdraw(year, static, 0.5, 20, 0.046, dt, 350000)[1]
# Out:
# start_date:  1980-01-01 00:00:00
# end_date:  2000-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2000-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2000-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2000-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2000-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2000-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2000-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2000-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2000-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2000-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2000-01-01 00:00:00
# ...

# %%
for year in range(1980, 1998) :
    p_val_25_10_m[year] = cons_withdraw(year, static, 0.5, 25, 0.044, dt, 350000)[0]
    p_val_25_20_m[year] = cons_withdraw(year, static, 0.5, 25, 0.042, dt, 350000)[0]
    p_val_25_30_m[year] = cons_withdraw(year, static, 0.5, 25, 0.04, dt, 350000)[0]
    p_val_25_40_m[year] = cons_withdraw(year, static, 0.5, 25, 0.039, dt, 350000)[0]
    p_val_25_50_m[year] = cons_withdraw(year, static, 0.5, 25, 0.037, dt, 350000)[0]
    p_val_25_60_m[year] = cons_withdraw(year, static, 0.5, 25, 0.036, dt, 350000)[0]
    p_val_25_70_m[year] = cons_withdraw(year, static, 0.5, 25, 0.034, dt, 350000)[0]
    p_val_25_80_m[year] = cons_withdraw(year, static, 0.5, 25, 0.031, dt, 350000)[0]
    p_val_25_90_m[year] = cons_withdraw(year, static, 0.5, 25, 0.026, dt, 350000)[0]

    p_val_25_10_p[year] = cons_withdraw(year, static, 0.5, 25, 0.064, dt, 350000)[0]
    p_val_25_20_p[year] = cons_withdraw(year, static, 0.5, 25, 0.062, dt, 350000)[0]
    p_val_25_30_p[year] = cons_withdraw(year, static, 0.5, 25, 0.06, dt, 350000)[0]
    p_val_25_40_p[year] = cons_withdraw(year, static, 0.5, 25, 0.059, dt, 350000)[0]
    p_val_25_50_p[year] = cons_withdraw(year, static, 0.5, 25, 0.057, dt, 350000)[0]
    p_val_25_60_p[year] = cons_withdraw(year, static, 0.5, 25, 0.056, dt, 350000)[0]
    p_val_25_70_p[year] = cons_withdraw(year, static, 0.5, 25, 0.054, dt, 350000)[0]
    p_val_25_80_p[year] = cons_withdraw(year, static, 0.5, 25, 0.051, dt, 350000)[0]
    p_val_25_90_p[year] = cons_withdraw(year, static, 0.5, 25, 0.046, dt, 350000)[0]
    
    w_val_25_10_m[year] = cons_withdraw(year, static, 0.5, 25, 0.044, dt, 350000)[1]
    w_val_25_20_m[year] = cons_withdraw(year, static, 0.5, 25, 0.042, dt, 350000)[1]
    w_val_25_30_m[year] = cons_withdraw(year, static, 0.5, 25, 0.04, dt, 350000)[1]
    w_val_25_40_m[year] = cons_withdraw(year, static, 0.5, 25, 0.039, dt, 350000)[1]
    w_val_25_50_m[year] = cons_withdraw(year, static, 0.5, 25, 0.037, dt, 350000)[1]
    w_val_25_60_m[year] = cons_withdraw(year, static, 0.5, 25, 0.036, dt, 350000)[1]
    w_val_25_70_m[year] = cons_withdraw(year, static, 0.5, 25, 0.034, dt, 350000)[1]
    w_val_25_80_m[year] = cons_withdraw(year, static, 0.5, 25, 0.031, dt, 350000)[1]
    w_val_25_90_m[year] = cons_withdraw(year, static, 0.5, 25, 0.026, dt, 350000)[1]
    
    w_val_25_10_p[year] = cons_withdraw(year, static, 0.5, 25, 0.064, dt, 350000)[1]
    w_val_25_20_p[year] = cons_withdraw(year, static, 0.5, 25, 0.062, dt, 350000)[1]
    w_val_25_30_p[year] = cons_withdraw(year, static, 0.5, 25, 0.06, dt, 350000)[1]
    w_val_25_40_p[year] = cons_withdraw(year, static, 0.5, 25, 0.059, dt, 350000)[1]
    w_val_25_50_p[year] = cons_withdraw(year, static, 0.5, 25, 0.057, dt, 350000)[1]
    w_val_25_60_p[year] = cons_withdraw(year, static, 0.5, 25, 0.056, dt, 350000)[1]
    w_val_25_70_p[year] = cons_withdraw(year, static, 0.5, 25, 0.054, dt, 350000)[1]
    w_val_25_80_p[year] = cons_withdraw(year, static, 0.5, 25, 0.051, dt, 350000)[1]
    w_val_25_90_p[year] = cons_withdraw(year, static, 0.5, 25, 0.046, dt, 350000)[1]
# Out:
# start_date:  1980-01-01 00:00:00
# end_date:  2005-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2005-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2005-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2005-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2005-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2005-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2005-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2005-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2005-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2005-01-01 00:00:00
# initial_weight:  0.5
# start_date:  1980-01-01 00:00:00
# end_date:  2005-01-01 00:00:00
# ...

# %%
p_val_25_10_m.to_csv(path + 'year25_p10_m_pval.csv')
p_val_25_20_m.to_csv(path + 'year25_p20_m_pval.csv')
p_val_25_30_m.to_csv(path + 'year25_p30_m_pval.csv')
p_val_25_40_m.to_csv(path + 'year25_p40_m_pval.csv')
p_val_25_50_m.to_csv(path + 'year25_p50_m_pval.csv')
p_val_25_60_m.to_csv(path + 'year25_p60_m_pval.csv')
p_val_25_70_m.to_csv(path + 'year25_p70_m_pval.csv')
p_val_25_80_m.to_csv(path + 'year25_p80_m_pval.csv')
p_val_25_90_m.to_csv(path + 'year25_p90_m_pval.csv')

p_val_30_10_m.to_csv(path + 'year30_p10_m_pval.csv')
p_val_30_20_m.to_csv(path + 'year30_p20_m_pval.csv')
p_val_30_30_m.to_csv(path + 'year30_p30_m_pval.csv')
p_val_30_40_m.to_csv(path + 'year30_p40_m_pval.csv')
p_val_30_50_m.to_csv(path + 'year30_p50_m_pval.csv')
p_val_30_60_m.to_csv(path + 'year30_p60_m_pval.csv')
p_val_30_70_m.to_csv(path + 'year30_p70_m_pval.csv')
p_val_30_80_m.to_csv(path + 'year30_p80_m_pval.csv')
p_val_30_90_m.to_csv(path + 'year30_p90_m_pval.csv')

p_val_20_10_m.to_csv(path + 'year20_p10_m_pval.csv')
p_val_20_20_m.to_csv(path + 'year20_p20_m_pval.csv')
p_val_20_30_m.to_csv(path + 'year20_p30_m_pval.csv')
p_val_20_40_m.to_csv(path + 'year20_p40_m_pval.csv')
p_val_20_50_m.to_csv(path + 'year20_p50_m_pval.csv')
p_val_20_60_m.to_csv(path + 'year20_p60_m_pval.csv')
p_val_20_70_m.to_csv(path + 'year20_p70_m_pval.csv')
p_val_20_80_m.to_csv(path + 'year20_p80_m_pval.csv')
p_val_20_90_m.to_csv(path + 'year20_p90_m_pval.csv')

p_val_25_10_p.to_csv(path + 'year25_p10_p_pval.csv')
p_val_25_20_p.to_csv(path + 'year25_p20_p_pval.csv')
p_val_25_30_p.to_csv(path + 'year25_p30_p_pval.csv')
p_val_25_40_p.to_csv(path + 'year25_p40_p_pval.csv')
p_val_25_50_p.to_csv(path + 'year25_p50_p_pval.csv')
p_val_25_60_p.to_csv(path + 'year25_p60_p_pval.csv')
p_val_25_70_p.to_csv(path + 'year25_p70_p_pval.csv')
p_val_25_80_p.to_csv(path + 'year25_p80_p_pval.csv')
p_val_25_90_p.to_csv(path + 'year25_p90_p_pval.csv')

p_val_30_10_p.to_csv(path + 'year30_p10_p_pval.csv')
p_val_30_20_p.to_csv(path + 'year30_p20_p_pval.csv')
p_val_30_30_p.to_csv(path + 'year30_p30_p_pval.csv')
p_val_30_40_p.to_csv(path + 'year30_p40_p_pval.csv')
p_val_30_50_p.to_csv(path + 'year30_p50_p_pval.csv')
p_val_30_60_p.to_csv(path + 'year30_p60_p_pval.csv')
p_val_30_70_p.to_csv(path + 'year30_p70_p_pval.csv')
p_val_30_80_p.to_csv(path + 'year30_p80_p_pval.csv')
p_val_30_90_p.to_csv(path + 'year30_p90_p_pval.csv')

p_val_20_10_p.to_csv(path + 'year20_p10_p_pval.csv')
p_val_20_20_p.to_csv(path + 'year20_p20_p_pval.csv')
p_val_20_30_p.to_csv(path + 'year20_p30_p_pval.csv')
p_val_20_40_p.to_csv(path + 'year20_p40_p_pval.csv')
p_val_20_50_p.to_csv(path + 'year20_p50_p_pval.csv')
p_val_20_60_p.to_csv(path + 'year20_p60_p_pval.csv')
p_val_20_70_p.to_csv(path + 'year20_p70_p_pval.csv')
p_val_20_80_p.to_csv(path + 'year20_p80_p_pval.csv')
p_val_20_90_p.to_csv(path + 'year20_p90_p_pval.csv')

# %%
w_val_25_10_m.to_csv(path + 'year25_p10_m_wval.csv')
w_val_25_20_m.to_csv(path + 'year25_p20_m_wval.csv')
w_val_25_30_m.to_csv(path + 'year25_p30_m_wval.csv')
w_val_25_40_m.to_csv(path + 'year25_p40_m_wval.csv')
w_val_25_50_m.to_csv(path + 'year25_p50_m_wval.csv')
w_val_25_60_m.to_csv(path + 'year25_p60_m_wval.csv')
w_val_25_70_m.to_csv(path + 'year25_p70_m_wval.csv')
w_val_25_80_m.to_csv(path + 'year25_p80_m_wval.csv')
w_val_25_90_m.to_csv(path + 'year25_p90_m_wval.csv')

w_val_30_10_m.to_csv(path + 'year30_p10_m_wval.csv')
w_val_30_20_m.to_csv(path + 'year30_p20_m_wval.csv')
w_val_30_30_m.to_csv(path + 'year30_p30_m_wval.csv')
w_val_30_40_m.to_csv(path + 'year30_p40_m_wval.csv')
w_val_30_50_m.to_csv(path + 'year30_p50_m_wval.csv')
w_val_30_60_m.to_csv(path + 'year30_p60_m_wval.csv')
w_val_30_70_m.to_csv(path + 'year30_p70_m_wval.csv')
w_val_30_80_m.to_csv(path + 'year30_p80_m_wval.csv')
w_val_30_90_m.to_csv(path + 'year30_p90_m_wval.csv')

w_val_20_10_m.to_csv(path + 'year20_p10_m_wval.csv')
w_val_20_20_m.to_csv(path + 'year20_p20_m_wval.csv')
w_val_20_30_m.to_csv(path + 'year20_p30_m_wval.csv')
w_val_20_40_m.to_csv(path + 'year20_p40_m_wval.csv')
w_val_20_50_m.to_csv(path + 'year20_p50_m_wval.csv')
w_val_20_60_m.to_csv(path + 'year20_p60_m_wval.csv')
w_val_20_70_m.to_csv(path + 'year20_p70_m_wval.csv')
w_val_20_80_m.to_csv(path + 'year20_p80_m_wval.csv')
w_val_20_90_m.to_csv(path + 'year20_p90_m_wval.csv')

w_val_25_10_p.to_csv(path + 'year25_p10_p_wval.csv')
w_val_25_20_p.to_csv(path + 'year25_p20_p_wval.csv')
w_val_25_30_p.to_csv(path + 'year25_p30_p_wval.csv')
w_val_25_40_p.to_csv(path + 'year25_p40_p_wval.csv')
w_val_25_50_p.to_csv(path + 'year25_p50_p_wval.csv')
w_val_25_60_p.to_csv(path + 'year25_p60_p_wval.csv')
w_val_25_70_p.to_csv(path + 'year25_p70_p_wval.csv')
w_val_25_80_p.to_csv(path + 'year25_p80_p_wval.csv')
w_val_25_90_p.to_csv(path + 'year25_p90_p_wval.csv')

w_val_30_10_p.to_csv(path + 'year30_p10_p_wval.csv')
w_val_30_20_p.to_csv(path + 'year30_p20_p_wval.csv')
w_val_30_30_p.to_csv(path + 'year30_p30_p_wval.csv')
w_val_30_40_p.to_csv(path + 'year30_p40_p_wval.csv')
w_val_30_50_p.to_csv(path + 'year30_p50_p_wval.csv')
w_val_30_60_p.to_csv(path + 'year30_p60_p_wval.csv')
w_val_30_70_p.to_csv(path + 'year30_p70_p_wval.csv')
w_val_30_80_p.to_csv(path + 'year30_p80_p_wval.csv')
w_val_30_90_p.to_csv(path + 'year30_p90_p_wval.csv')

w_val_20_10_p.to_csv(path + 'year20_p10_p_wval.csv')
w_val_20_20_p.to_csv(path + 'year20_p20_p_wval.csv')
w_val_20_30_p.to_csv(path + 'year20_p30_p_wval.csv')
w_val_20_40_p.to_csv(path + 'year20_p40_p_wval.csv')
w_val_20_50_p.to_csv(path + 'year20_p50_p_wval.csv')
w_val_20_60_p.to_csv(path + 'year20_p60_p_wval.csv')
w_val_20_70_p.to_csv(path + 'year20_p70_p_wval.csv')
w_val_20_80_p.to_csv(path + 'year20_p80_p_wval.csv')
w_val_20_90_p.to_csv(path + 'year20_p90_p_wval.csv')

# %%
p_val ={}

p_val['p_val_20_p10'] = [p_val_20_10_m, p_val_20_10_p]
p_val['p_val_20_p20'] = [p_val_20_20_m, p_val_20_20_p]
p_val['p_val_20_p30'] = [p_val_20_30_m, p_val_20_30_p]
p_val['p_val_20_p40'] = [p_val_20_40_m, p_val_20_40_p]
p_val['p_val_20_p50'] = [p_val_20_50_m, p_val_20_50_p]
p_val['p_val_20_p60'] = [p_val_20_60_m, p_val_20_60_p]
p_val['p_val_20_p70'] = [p_val_20_70_m, p_val_20_70_p]
p_val['p_val_20_p80'] = [p_val_20_80_m, p_val_20_80_p]
p_val['p_val_20_p90'] = [p_val_20_90_m, p_val_20_90_p]

p_val['p_val_25_p10'] = [p_val_25_10_m, p_val_25_10_p]
p_val['p_val_25_p20'] = [p_val_25_20_m, p_val_25_20_p]
p_val['p_val_25_p30'] = [p_val_25_30_m, p_val_25_30_p]
p_val['p_val_25_p40'] = [p_val_25_40_m, p_val_25_40_p]
p_val['p_val_25_p50'] = [p_val_25_50_m, p_val_25_50_p]
p_val['p_val_25_p60'] = [p_val_25_60_m, p_val_25_60_p]
p_val['p_val_25_p70'] = [p_val_25_70_m, p_val_25_70_p]
p_val['p_val_25_p80'] = [p_val_25_80_m, p_val_25_80_p]
p_val['p_val_25_p90'] = [p_val_25_90_m, p_val_25_90_p]

p_val['p_val_30_p10'] = [p_val_30_10_m, p_val_30_10_p]
p_val['p_val_30_p20'] = [p_val_30_20_m, p_val_30_20_p]
p_val['p_val_30_p30'] = [p_val_30_30_m, p_val_30_30_p]
p_val['p_val_30_p40'] = [p_val_30_40_m, p_val_30_40_p]
p_val['p_val_30_p50'] = [p_val_30_50_m, p_val_30_50_p]
p_val['p_val_30_p60'] = [p_val_30_60_m, p_val_30_60_p]
p_val['p_val_30_p70'] = [p_val_30_70_m, p_val_30_70_p]
p_val['p_val_30_p80'] = [p_val_30_80_m, p_val_30_80_p]
p_val['p_val_30_p90'] = [p_val_30_90_m, p_val_30_90_p]

# %%
p_val =pd.DataFrame(p_val, index = ['minimum', 'proper'])

# %%
w_val ={}

w_val['w_val_20_p10'] = [w_val_20_10_m, w_val_20_10_p]
w_val['w_val_20_p20'] = [w_val_20_20_m, w_val_20_20_p]
w_val['w_val_20_p30'] = [w_val_20_30_m, w_val_20_30_p]
w_val['w_val_20_p40'] = [w_val_20_40_m, w_val_20_40_p]
w_val['w_val_20_p50'] = [w_val_20_50_m, w_val_20_50_p]
w_val['w_val_20_p60'] = [w_val_20_60_m, w_val_20_60_p]
w_val['w_val_20_p70'] = [w_val_20_70_m, w_val_20_70_p]
w_val['w_val_20_p80'] = [w_val_20_80_m, w_val_20_80_p]
w_val['w_val_20_p90'] = [w_val_20_90_m, w_val_20_90_p]

w_val['w_val_25_p10'] = [w_val_25_10_m, w_val_25_10_p]
w_val['w_val_25_p20'] = [w_val_25_20_m, w_val_25_20_p]
w_val['w_val_25_p30'] = [w_val_25_30_m, w_val_25_30_p]
w_val['w_val_25_p40'] = [w_val_25_40_m, w_val_25_40_p]
w_val['w_val_25_p50'] = [w_val_25_50_m, w_val_25_50_p]
w_val['w_val_25_p60'] = [w_val_25_60_m, w_val_25_60_p]
w_val['w_val_25_p70'] = [w_val_25_70_m, w_val_25_70_p]
w_val['w_val_25_p80'] = [w_val_25_80_m, w_val_25_80_p]
w_val['w_val_25_p90'] = [w_val_25_90_m, w_val_25_90_p]

w_val['w_val_30_p10'] = [w_val_30_10_m, w_val_30_10_p]
w_val['w_val_30_p20'] = [w_val_30_20_m, w_val_30_20_p]
w_val['w_val_30_p30'] = [w_val_30_30_m, w_val_30_30_p]
w_val['w_val_30_p40'] = [w_val_30_40_m, w_val_30_40_p]
w_val['w_val_30_p50'] = [w_val_30_50_m, w_val_30_50_p]
w_val['w_val_30_p60'] = [w_val_30_60_m, w_val_30_60_p]
w_val['w_val_30_p70'] = [w_val_30_70_m, w_val_30_70_p]
w_val['w_val_30_p80'] = [w_val_30_80_m, w_val_30_80_p]
w_val['w_val_30_p90'] = [w_val_30_90_m, w_val_30_90_p]

# %%
w_val =pd.DataFrame(w_val, index = ['minimum', 'proper'])

# %%
p_val.to_pickle(path + 'p_val.pkl')
w_val.to_pickle(path + 'w_val.pkl')

# %%
dic ={}

for year in range(1980, 1993) :
    dic[year] = [0]
    
dic_2 ={}

for year in range(1980, 2003) :
    dic_2[year] = [0]
    
dic_3 ={}

for year in range(1980, 1998) :
    dic_3[year] = [0]

# %%
beq_30_10_m = pd.DataFrame(dic)
beq_30_20_m = pd.DataFrame(dic)
beq_30_30_m = pd.DataFrame(dic)
beq_30_40_m = pd.DataFrame(dic)
beq_30_50_m = pd.DataFrame(dic)
beq_30_60_m = pd.DataFrame(dic)
beq_30_70_m = pd.DataFrame(dic)
beq_30_80_m = pd.DataFrame(dic)
beq_30_90_m = pd.DataFrame(dic)

beq_20_10_m = pd.DataFrame(dic_2)
beq_20_20_m = pd.DataFrame(dic_2)
beq_20_30_m = pd.DataFrame(dic_2)
beq_20_40_m = pd.DataFrame(dic_2)
beq_20_50_m = pd.DataFrame(dic_2)
beq_20_60_m = pd.DataFrame(dic_2)
beq_20_70_m = pd.DataFrame(dic_2)
beq_20_80_m = pd.DataFrame(dic_2)
beq_20_90_m = pd.DataFrame(dic_2)

beq_25_10_m = pd.DataFrame(dic_3)
beq_25_20_m = pd.DataFrame(dic_3)
beq_25_30_m = pd.DataFrame(dic_3)
beq_25_40_m = pd.DataFrame(dic_3)
beq_25_50_m = pd.DataFrame(dic_3)
beq_25_60_m = pd.DataFrame(dic_3)
beq_25_70_m = pd.DataFrame(dic_3)
beq_25_80_m = pd.DataFrame(dic_3)
beq_25_90_m = pd.DataFrame(dic_3)

beq_30_10_p = pd.DataFrame(dic)
beq_30_20_p = pd.DataFrame(dic)
beq_30_30_p = pd.DataFrame(dic)
beq_30_40_p = pd.DataFrame(dic)
beq_30_50_p = pd.DataFrame(dic)
beq_30_60_p = pd.DataFrame(dic)
beq_30_70_p = pd.DataFrame(dic)
beq_30_80_p = pd.DataFrame(dic)
beq_30_90_p = pd.DataFrame(dic)

beq_20_10_p = pd.DataFrame(dic_2)
beq_20_20_p = pd.DataFrame(dic_2)
beq_20_30_p = pd.DataFrame(dic_2)
beq_20_40_p = pd.DataFrame(dic_2)
beq_20_50_p = pd.DataFrame(dic_2)
beq_20_60_p = pd.DataFrame(dic_2)
beq_20_70_p = pd.DataFrame(dic_2)
beq_20_80_p = pd.DataFrame(dic_2)
beq_20_90_p = pd.DataFrame(dic_2)

beq_25_10_p = pd.DataFrame(dic_3)
beq_25_20_p = pd.DataFrame(dic_3)
beq_25_30_p = pd.DataFrame(dic_3)
beq_25_40_p = pd.DataFrame(dic_3)
beq_25_50_p = pd.DataFrame(dic_3)
beq_25_60_p = pd.DataFrame(dic_3)
beq_25_70_p = pd.DataFrame(dic_3)
beq_25_80_p = pd.DataFrame(dic_3)
beq_25_90_p = pd.DataFrame(dic_3)

# %%
inc_30_10_m = pd.DataFrame(dic)
inc_30_20_m = pd.DataFrame(dic)
inc_30_30_m = pd.DataFrame(dic)
inc_30_40_m = pd.DataFrame(dic)
inc_30_50_m = pd.DataFrame(dic)
inc_30_60_m = pd.DataFrame(dic)
inc_30_70_m = pd.DataFrame(dic)
inc_30_80_m = pd.DataFrame(dic)
inc_30_90_m = pd.DataFrame(dic)

inc_20_10_m = pd.DataFrame(dic_2)
inc_20_20_m = pd.DataFrame(dic_2)
inc_20_30_m = pd.DataFrame(dic_2)
inc_20_40_m = pd.DataFrame(dic_2)
inc_20_50_m = pd.DataFrame(dic_2)
inc_20_60_m = pd.DataFrame(dic_2)
inc_20_70_m = pd.DataFrame(dic_2)
inc_20_80_m = pd.DataFrame(dic_2)
inc_20_90_m = pd.DataFrame(dic_2)

inc_25_10_m = pd.DataFrame(dic_3)
inc_25_20_m = pd.DataFrame(dic_3)
inc_25_30_m = pd.DataFrame(dic_3)
inc_25_40_m = pd.DataFrame(dic_3)
inc_25_50_m = pd.DataFrame(dic_3)
inc_25_60_m = pd.DataFrame(dic_3)
inc_25_70_m = pd.DataFrame(dic_3)
inc_25_80_m = pd.DataFrame(dic_3)
inc_25_90_m = pd.DataFrame(dic_3)

inc_30_10_p = pd.DataFrame(dic)
inc_30_20_p = pd.DataFrame(dic)
inc_30_30_p = pd.DataFrame(dic)
inc_30_40_p = pd.DataFrame(dic)
inc_30_50_p = pd.DataFrame(dic)
inc_30_60_p = pd.DataFrame(dic)
inc_30_70_p = pd.DataFrame(dic)
inc_30_80_p = pd.DataFrame(dic)
inc_30_90_p = pd.DataFrame(dic)

inc_20_10_p = pd.DataFrame(dic_2)
inc_20_20_p = pd.DataFrame(dic_2)
inc_20_30_p = pd.DataFrame(dic_2)
inc_20_40_p = pd.DataFrame(dic_2)
inc_20_50_p = pd.DataFrame(dic_2)
inc_20_60_p = pd.DataFrame(dic_2)
inc_20_70_p = pd.DataFrame(dic_2)
inc_20_80_p = pd.DataFrame(dic_2)
inc_20_90_p = pd.DataFrame(dic_2)

inc_25_10_p = pd.DataFrame(dic_3)
inc_25_20_p = pd.DataFrame(dic_3)
inc_25_30_p = pd.DataFrame(dic_3)
inc_25_40_p = pd.DataFrame(dic_3)
inc_25_50_p = pd.DataFrame(dic_3)
inc_25_60_p = pd.DataFrame(dic_3)
inc_25_70_p = pd.DataFrame(dic_3)
inc_25_80_p = pd.DataFrame(dic_3)
inc_25_90_p = pd.DataFrame(dic_3)

# %%
dep_30_10_m = pd.DataFrame(dic)
dep_30_20_m = pd.DataFrame(dic)
dep_30_30_m = pd.DataFrame(dic)
dep_30_40_m = pd.DataFrame(dic)
dep_30_50_m = pd.DataFrame(dic)
dep_30_60_m = pd.DataFrame(dic)
dep_30_70_m = pd.DataFrame(dic)
dep_30_80_m = pd.DataFrame(dic)
dep_30_90_m = pd.DataFrame(dic)

dep_20_10_m = pd.DataFrame(dic_2)
dep_20_20_m = pd.DataFrame(dic_2)
dep_20_30_m = pd.DataFrame(dic_2)
dep_20_40_m = pd.DataFrame(dic_2)
dep_20_50_m = pd.DataFrame(dic_2)
dep_20_60_m = pd.DataFrame(dic_2)
dep_20_70_m = pd.DataFrame(dic_2)
dep_20_80_m = pd.DataFrame(dic_2)
dep_20_90_m = pd.DataFrame(dic_2)

dep_25_10_m = pd.DataFrame(dic_3)
dep_25_20_m = pd.DataFrame(dic_3)
dep_25_30_m = pd.DataFrame(dic_3)
dep_25_40_m = pd.DataFrame(dic_3)
dep_25_50_m = pd.DataFrame(dic_3)
dep_25_60_m = pd.DataFrame(dic_3)
dep_25_70_m = pd.DataFrame(dic_3)
dep_25_80_m = pd.DataFrame(dic_3)
dep_25_90_m = pd.DataFrame(dic_3)

dep_30_10_p = pd.DataFrame(dic)
dep_30_20_p= pd.DataFrame(dic)
dep_30_30_p = pd.DataFrame(dic)
dep_30_40_p = pd.DataFrame(dic)
dep_30_50_p = pd.DataFrame(dic)
dep_30_60_p = pd.DataFrame(dic)
dep_30_70_p = pd.DataFrame(dic)
dep_30_80_p = pd.DataFrame(dic)
dep_30_90_p = pd.DataFrame(dic)

dep_20_10_p = pd.DataFrame(dic_2)
dep_20_20_p = pd.DataFrame(dic_2)
dep_20_30_p = pd.DataFrame(dic_2)
dep_20_40_p = pd.DataFrame(dic_2)
dep_20_50_p = pd.DataFrame(dic_2)
dep_20_60_p = pd.DataFrame(dic_2)
dep_20_70_p = pd.DataFrame(dic_2)
dep_20_80_p = pd.DataFrame(dic_2)
dep_20_90_p = pd.DataFrame(dic_2)

dep_25_10_p = pd.DataFrame(dic_3)
dep_25_20_p = pd.DataFrame(dic_3)
dep_25_30_p = pd.DataFrame(dic_3)
dep_25_40_p = pd.DataFrame(dic_3)
dep_25_50_p = pd.DataFrame(dic_3)
dep_25_60_p = pd.DataFrame(dic_3)
dep_25_70_p = pd.DataFrame(dic_3)
dep_25_80_p = pd.DataFrame(dic_3)
dep_25_90_p = pd.DataFrame(dic_3)

# %%
for year in range(1980, 2003) :
    beq_20_10_m[year] = p_val_20_10_m[year].iloc[-1]
    inc_20_10_m[year] = w_val_20_10_m[year].iloc[-1]
    if p_val_20_10_m[year].iloc[-1] == 0 :
        dep_20_10_m[year] = 1
    else :
        dep_20_10_m[year] = 0
    
    beq_20_20_m[year] = p_val_20_20_m[year].iloc[-1]
    inc_20_20_m[year] = w_val_20_20_m[year].iloc[-1]
    if p_val_20_20_m[year].iloc[-1] == 0 :
        dep_20_20_m[year] = 1
    else :
        dep_20_20_m[year] = 0
    
    beq_20_30_m[year] = p_val_20_30_m[year].iloc[-1]
    inc_20_30_m[year] = w_val_20_30_m[year].iloc[-1]
    if p_val_20_30_m[year].iloc[-1] == 0 :
        dep_20_30_m[year] = 1
    else :
        dep_20_30_m[year] = 0
        
    beq_20_40_m[year] = p_val_20_40_m[year].iloc[-1]
    inc_20_40_m[year] = w_val_20_40_m[year].iloc[-1]
    if p_val_20_40_m[year].iloc[-1] == 0 :
        dep_20_40_m[year] = 1
    else :
        dep_20_40_m[year] = 0
        
    beq_20_50_m[year] = p_val_20_50_m[year].iloc[-1]
    inc_20_50_m[year] = w_val_20_50_m[year].iloc[-1]
    if p_val_20_50_m[year].iloc[-1] == 0 :
        dep_20_50_m[year] = 1
    else :
        dep_20_50_m[year] = 0
        
    beq_20_60_m[year] = p_val_20_60_m[year].iloc[-1]
    inc_20_60_m[year] = w_val_20_60_m[year].iloc[-1]
    if p_val_20_60_m[year].iloc[-1] == 0 :
        dep_20_60_m[year] = 1
    else :
        dep_20_60_m[year] = 0
        
    beq_20_70_m[year] = p_val_20_70_m[year].iloc[-1]
    inc_20_70_m[year] = w_val_20_70_m[year].iloc[-1]
    if p_val_20_70_m[year].iloc[-1] == 0 :
        dep_20_70_m[year] = 1
    else :
        dep_20_70_m[year] = 0
        
    beq_20_80_m[year] = p_val_20_80_m[year].iloc[-1]
    inc_20_80_m[year] = w_val_20_80_m[year].iloc[-1]
    if p_val_20_80_m[year].iloc[-1] == 0 :
        dep_20_80_m[year] = 1
    else :
        dep_20_80_m[year] = 0
        
    beq_20_90_m[year] = p_val_20_90_m[year].iloc[-1]
    inc_20_90_m[year] = w_val_20_90_m[year].iloc[-1]
    if p_val_20_90_m[year].iloc[-1] == 0 :
        dep_20_90_m[year] = 1
    else :
        dep_20_90_m[year] = 0
        
    beq_20_10_p[year] = p_val_20_10_p[year].iloc[-1]
    inc_20_10_p[year] = w_val_20_10_p[year].iloc[-1]
    if p_val_20_10_p[year].iloc[-1] == 0 :
        dep_20_10_p[year] = 1
    else :
        dep_20_10_p[year] = 0
    
    beq_20_20_p[year] = p_val_20_20_p[year].iloc[-1]
    inc_20_20_p[year] = w_val_20_20_p[year].iloc[-1]
    if p_val_20_20_p[year].iloc[-1] == 0 :
        dep_20_20_p[year] = 1
    else :
        dep_20_20_p[year] = 0
    
    beq_20_30_p[year] = p_val_20_30_p[year].iloc[-1]
    inc_20_30_p[year] = w_val_20_30_p[year].iloc[-1]
    if p_val_20_30_p[year].iloc[-1] == 0 :
        dep_20_30_p[year] = 1
    else :
        dep_20_30_p[year] = 0
        
    beq_20_40_p[year] = p_val_20_40_p[year].iloc[-1]
    inc_20_40_p[year] = w_val_20_40_p[year].iloc[-1]
    if p_val_20_40_p[year].iloc[-1] == 0 :
        dep_20_40_p[year] = 1
    else :
        dep_20_40_p[year] = 0
        
    beq_20_50_p[year] = p_val_20_50_p[year].iloc[-1]
    inc_20_50_p[year] = w_val_20_50_p[year].iloc[-1]
    if p_val_20_50_p[year].iloc[-1] == 0 :
        dep_20_50_p[year] = 1
    else :
        dep_20_50_p[year] = 0
        
    beq_20_60_p[year] = p_val_20_60_p[year].iloc[-1]
    inc_20_60_p[year] = w_val_20_60_p[year].iloc[-1]
    if p_val_20_60_p[year].iloc[-1] == 0 :
        dep_20_60_p[year] = 1
    else :
        dep_20_60_p[year] = 0
        
    beq_20_70_p[year] = p_val_20_70_p[year].iloc[-1]
    inc_20_70_p[year] = w_val_20_70_p[year].iloc[-1]
    if p_val_20_70_p[year].iloc[-1] == 0 :
        dep_20_70_p[year] = 1
    else :
        dep_20_70_p[year] = 0
        
    beq_20_80_p[year] = p_val_20_80_p[year].iloc[-1]
    inc_20_80_p[year] = w_val_20_80_p[year].iloc[-1]
    if p_val_20_80_p[year].iloc[-1] == 0 :
        dep_20_80_p[year] = 1
    else :
        dep_20_80_p[year] = 0
        
    beq_20_90_p[year] = p_val_20_90_p[year].iloc[-1]
    inc_20_90_p[year] = w_val_20_90_p[year].iloc[-1]
    if p_val_20_90_p[year].iloc[-1] == 0 :
        dep_20_90_p[year] = 1
    else :
        dep_20_90_p[year] = 0

# %%
for year in range(1980, 1998) :
    beq_25_10_m[year] = p_val_25_10_m[year].iloc[-1]
    inc_25_10_m[year] = w_val_25_10_m[year].iloc[-1]
    if p_val_25_10_m[year].iloc[-1] == 0 :
        dep_25_10_m[year] = 1
    else :
        dep_25_10_m[year] = 0
    
    beq_25_20_m[year] = p_val_25_20_m[year].iloc[-1]
    inc_25_20_m[year] = w_val_25_20_m[year].iloc[-1]
    if p_val_25_20_m[year].iloc[-1] == 0 :
        dep_25_20_m[year] = 1
    else :
        dep_25_20_m[year] = 0
    
    beq_25_30_m[year] = p_val_25_30_m[year].iloc[-1]
    inc_25_30_m[year] = w_val_25_30_m[year].iloc[-1]
    if p_val_25_30_m[year].iloc[-1] == 0 :
        dep_25_30_m[year] = 1
    else :
        dep_25_30_m[year] = 0
        
    beq_25_40_m[year] = p_val_25_40_m[year].iloc[-1]
    inc_25_40_m[year] = w_val_25_40_m[year].iloc[-1]
    if p_val_25_40_m[year].iloc[-1] == 0 :
        dep_25_40_m[year] = 1
    else :
        dep_25_40_m[year] = 0
        
    beq_25_50_m[year] = p_val_25_50_m[year].iloc[-1]
    inc_25_50_m[year] = w_val_25_50_m[year].iloc[-1]
    if p_val_25_50_m[year].iloc[-1] == 0 :
        dep_25_50_m[year] = 1
    else :
        dep_25_50_m[year] = 0
        
    beq_25_60_m[year] = p_val_25_60_m[year].iloc[-1]
    inc_25_60_m[year] = w_val_25_60_m[year].iloc[-1]
    if p_val_25_60_m[year].iloc[-1] == 0 :
        dep_25_60_m[year] = 1
    else :
        dep_25_60_m[year] = 0
        
    beq_25_70_m[year] = p_val_25_70_m[year].iloc[-1]
    inc_25_70_m[year] = w_val_25_70_m[year].iloc[-1]
    if p_val_25_70_m[year].iloc[-1] == 0 :
        dep_25_70_m[year] = 1
    else :
        dep_25_70_m[year] = 0
        
    beq_25_80_m[year] = p_val_25_80_m[year].iloc[-1]
    inc_25_80_m[year] = w_val_25_80_m[year].iloc[-1]
    if p_val_25_80_m[year].iloc[-1] == 0 :
        dep_25_80_m[year] = 1
    else :
        dep_25_80_m[year] = 0
        
    beq_25_90_m[year] = p_val_25_90_m[year].iloc[-1]
    inc_25_90_m[year] = w_val_25_90_m[year].iloc[-1]
    if p_val_25_90_m[year].iloc[-1] == 0 :
        dep_25_90_m[year] = 1
    else :
        dep_25_90_m[year] = 0
        
    beq_25_10_p[year] = p_val_25_10_p[year].iloc[-1]
    inc_25_10_p[year] = w_val_25_10_p[year].iloc[-1]
    if p_val_25_10_p[year].iloc[-1] == 0 :
        dep_25_10_p[year] = 1
    else :
        dep_25_10_p[year] = 0
    
    beq_25_20_p[year] = p_val_25_20_p[year].iloc[-1]
    inc_25_20_p[year] = w_val_25_20_p[year].iloc[-1]
    if p_val_25_20_p[year].iloc[-1] == 0 :
        dep_25_20_p[year] = 1
    else :
        dep_25_20_p[year] = 0
    
    beq_25_30_p[year] = p_val_25_30_p[year].iloc[-1]
    inc_25_30_p[year] = w_val_25_30_p[year].iloc[-1]
    if p_val_25_30_p[year].iloc[-1] == 0 :
        dep_25_30_p[year] = 1
    else :
        dep_25_30_p[year] = 0
        
    beq_25_40_p[year] = p_val_25_40_p[year].iloc[-1]
    inc_25_40_p[year] = w_val_25_40_p[year].iloc[-1]
    if p_val_25_40_p[year].iloc[-1] == 0 :
        dep_25_40_p[year] = 1
    else :
        dep_25_40_p[year] = 0
        
    beq_25_50_p[year] = p_val_25_50_p[year].iloc[-1]
    inc_25_50_p[year] = w_val_25_50_p[year].iloc[-1]
    if p_val_25_50_p[year].iloc[-1] == 0 :
        dep_25_50_p[year] = 1
    else :
        dep_25_50_p[year] = 0
        
    beq_25_60_p[year] = p_val_25_60_p[year].iloc[-1]
    inc_25_60_p[year] = w_val_25_60_p[year].iloc[-1]
    if p_val_25_60_p[year].iloc[-1] == 0 :
        dep_25_60_p[year] = 1
    else :
        dep_25_60_p[year] = 0
        
    beq_25_70_p[year] = p_val_25_70_p[year].iloc[-1]
    inc_25_70_p[year] = w_val_25_70_p[year].iloc[-1]
    if p_val_25_70_p[year].iloc[-1] == 0 :
        dep_25_70_p[year] = 1
    else :
        dep_25_70_p[year] = 0
        
    beq_25_80_p[year] = p_val_25_80_p[year].iloc[-1]
    inc_25_80_p[year] = w_val_25_80_p[year].iloc[-1]
    if p_val_25_80_p[year].iloc[-1] == 0 :
        dep_25_80_p[year] = 1
    else :
        dep_25_80_p[year] = 0
        
    beq_25_90_p[year] = p_val_25_90_p[year].iloc[-1]
    inc_25_90_p[year] = w_val_25_90_p[year].iloc[-1]
    if p_val_25_90_p[year].iloc[-1] == 0 :
        dep_25_90_p[year] = 1
    else :
        dep_25_90_p[year] = 0

# %%
for year in range(1980, 1993) :
    beq_30_10_m[year] = p_val_30_10_m[year].iloc[-1]
    inc_30_10_m[year] = w_val_30_10_m[year].iloc[-1]
    if p_val_30_10_m[year].iloc[-1] == 0 :
        dep_30_10_m[year] = 1
    else :
        dep_30_10_m[year] = 0
    
    beq_30_20_m[year] = p_val_30_20_m[year].iloc[-1]
    inc_30_20_m[year] = w_val_30_20_m[year].iloc[-1]
    if p_val_30_20_m[year].iloc[-1] == 0 :
        dep_30_20_m[year] = 1
    else :
        dep_30_20_m[year] = 0
    
    beq_30_30_m[year] = p_val_30_30_m[year].iloc[-1]
    inc_30_30_m[year] = w_val_30_30_m[year].iloc[-1]
    if p_val_30_30_m[year].iloc[-1] == 0 :
        dep_30_30_m[year] = 1
    else :
        dep_30_30_m[year] = 0
        
    beq_30_40_m[year] = p_val_30_40_m[year].iloc[-1]
    inc_30_40_m[year] = w_val_30_40_m[year].iloc[-1]
    if p_val_30_40_m[year].iloc[-1] == 0 :
        dep_30_40_m[year] = 1
    else :
        dep_30_40_m[year] = 0
        
    beq_30_50_m[year] = p_val_30_50_m[year].iloc[-1]
    inc_30_50_m[year] = w_val_30_50_m[year].iloc[-1]
    if p_val_30_50_m[year].iloc[-1] == 0 :
        dep_30_50_m[year] = 1
    else :
        dep_30_50_m[year] = 0
        
    beq_30_60_m[year] = p_val_30_60_m[year].iloc[-1]
    inc_30_60_m[year] = w_val_30_60_m[year].iloc[-1]
    if p_val_30_60_m[year].iloc[-1] == 0 :
        dep_30_60_m[year] = 1
    else :
        dep_30_60_m[year] = 0
        
    beq_30_70_m[year] = p_val_30_70_m[year].iloc[-1]
    inc_30_70_m[year] = w_val_30_70_m[year].iloc[-1]
    if p_val_30_70_m[year].iloc[-1] == 0 :
        dep_30_70_m[year] = 1
    else :
        dep_30_70_m[year] = 0
        
    beq_30_80_m[year] = p_val_30_80_m[year].iloc[-1]
    inc_30_80_m[year] = w_val_30_80_m[year].iloc[-1]
    if p_val_30_80_m[year].iloc[-1] == 0 :
        dep_30_80_m[year] = 1
    else :
        dep_30_80_m[year] = 0
        
    beq_30_90_m[year] = p_val_30_90_m[year].iloc[-1]
    inc_30_90_m[year] = w_val_30_90_m[year].iloc[-1]
    if p_val_30_90_m[year].iloc[-1] == 0 :
        dep_30_90_m[year] = 1
    else :
        dep_30_90_m[year] = 0
        
    beq_30_10_p[year] = p_val_30_10_p[year].iloc[-1]
    inc_30_10_p[year] = w_val_30_10_p[year].iloc[-1]
    if p_val_30_10_p[year].iloc[-1] == 0 :
        dep_30_10_p[year] = 1
    else :
        dep_30_10_p[year] = 0
    
    beq_30_20_p[year] = p_val_30_20_p[year].iloc[-1]
    inc_30_20_p[year] = w_val_30_20_p[year].iloc[-1]
    if p_val_30_20_p[year].iloc[-1] == 0 :
        dep_30_20_p[year] = 1
    else :
        dep_30_20_p[year] = 0
    
    beq_30_30_p[year] = p_val_30_30_p[year].iloc[-1]
    inc_30_30_p[year] = w_val_30_30_p[year].iloc[-1]
    if p_val_30_30_p[year].iloc[-1] == 0 :
        dep_30_30_p[year] = 1
    else :
        dep_30_30_p[year] = 0
        
    beq_30_40_p[year] = p_val_30_40_p[year].iloc[-1]
    inc_30_40_p[year] = w_val_30_40_p[year].iloc[-1]
    if p_val_30_40_p[year].iloc[-1] == 0 :
        dep_30_40_p[year] = 1
    else :
        dep_30_40_p[year] = 0
        
    beq_30_50_p[year] = p_val_30_50_p[year].iloc[-1]
    inc_30_50_p[year] = w_val_30_50_p[year].iloc[-1]
    if p_val_30_50_p[year].iloc[-1] == 0 :
        dep_30_50_p[year] = 1
    else :
        dep_30_50_p[year] = 0
        
    beq_30_60_p[year] = p_val_30_60_p[year].iloc[-1]
    inc_30_60_p[year] = w_val_30_60_p[year].iloc[-1]
    if p_val_30_60_p[year].iloc[-1] == 0 :
        dep_30_60_p[year] = 1
    else :
        dep_30_60_p[year] = 0
        
    beq_30_70_p[year] = p_val_30_70_p[year].iloc[-1]
    inc_30_70_p[year] = w_val_30_70_p[year].iloc[-1]
    if p_val_30_70_p[year].iloc[-1] == 0 :
        dep_30_70_p[year] = 1
    else :
        dep_30_70_p[year] = 0
        
    beq_30_80_p[year] = p_val_30_80_p[year].iloc[-1]
    inc_30_80_p[year] = w_val_30_80_p[year].iloc[-1]
    if p_val_30_80_p[year].iloc[-1] == 0 :
        dep_30_80_p[year] = 1
    else :
        dep_30_80_p[year] = 0
        
    beq_30_90_p[year] = p_val_30_90_p[year].iloc[-1]
    inc_30_90_p[year] = w_val_30_90_p[year].iloc[-1]
    if p_val_30_90_p[year].iloc[-1] == 0 :
        dep_30_90_p[year] = 1
    else :
        dep_30_90_p[year] = 0

# %%
beq ={}

beq['beq_20_p10'] = [beq_20_10_m, beq_20_10_p]
beq['beq_20_p20'] = [beq_20_20_m, beq_20_20_p]
beq['beq_20_p30'] = [beq_20_30_m, beq_20_30_p]
beq['beq_20_p40'] = [beq_20_40_m, beq_20_40_p]
beq['beq_20_p50'] = [beq_20_50_m, beq_20_50_p]
beq['beq_20_p60'] = [beq_20_60_m, beq_20_60_p]
beq['beq_20_p70'] = [beq_20_70_m, beq_20_70_p]
beq['beq_20_p80'] = [beq_20_80_m, beq_20_80_p]
beq['beq_20_p90'] = [beq_20_90_m, beq_20_90_p]

beq['beq_25_p10'] = [beq_25_10_m, beq_25_10_p]
beq['beq_25_p20'] = [beq_25_20_m, beq_25_20_p]
beq['beq_25_p30'] = [beq_25_30_m, beq_25_30_p]
beq['beq_25_p40'] = [beq_25_40_m, beq_25_40_p]
beq['beq_25_p50'] = [beq_25_50_m, beq_25_50_p]
beq['beq_25_p60'] = [beq_25_60_m, beq_25_60_p]
beq['beq_25_p70'] = [beq_25_70_m, beq_25_70_p]
beq['beq_25_p80'] = [beq_25_80_m, beq_25_80_p]
beq['beq_25_p90'] = [beq_25_90_m, beq_25_90_p]

beq['beq_30_p10'] = [beq_30_10_m, beq_30_10_p]
beq['beq_30_p20'] = [beq_30_20_m, beq_30_20_p]
beq['beq_30_p30'] = [beq_30_30_m, beq_30_30_p]
beq['beq_30_p40'] = [beq_30_40_m, beq_30_40_p]
beq['beq_30_p50'] = [beq_30_50_m, beq_30_50_p]
beq['beq_30_p60'] = [beq_30_60_m, beq_30_60_p]
beq['beq_30_p70'] = [beq_30_70_m, beq_30_70_p]
beq['beq_30_p80'] = [beq_30_80_m, beq_30_80_p]
beq['beq_30_p90'] = [beq_30_90_m, beq_30_90_p]

# %%
inc ={}

inc['inc_20_p10'] = [inc_20_10_m, inc_20_10_p]
inc['inc_20_p20'] = [inc_20_20_m, inc_20_20_p]
inc['inc_20_p30'] = [inc_20_30_m, inc_20_30_p]
inc['inc_20_p40'] = [inc_20_40_m, inc_20_40_p]
inc['inc_20_p50'] = [inc_20_50_m, inc_20_50_p]
inc['inc_20_p60'] = [inc_20_60_m, inc_20_60_p]
inc['inc_20_p70'] = [inc_20_70_m, inc_20_70_p]
inc['inc_20_p80'] = [inc_20_80_m, inc_20_80_p]
inc['inc_20_p90'] = [inc_20_90_m, inc_20_90_p]

inc['inc_25_p10'] = [inc_25_10_m, inc_25_10_p]
inc['inc_25_p20'] = [inc_25_20_m, inc_25_20_p]
inc['inc_25_p30'] = [inc_25_30_m, inc_25_30_p]
inc['inc_25_p40'] = [inc_25_40_m, inc_25_40_p]
inc['inc_25_p50'] = [inc_25_50_m, inc_25_50_p]
inc['inc_25_p60'] = [inc_25_60_m, inc_25_60_p]
inc['inc_25_p70'] = [inc_25_70_m, inc_25_70_p]
inc['inc_25_p80'] = [inc_25_80_m, inc_25_80_p]
inc['inc_25_p90'] = [inc_25_90_m, inc_25_90_p]

inc['inc_30_p10'] = [inc_30_10_m, inc_30_10_p]
inc['inc_30_p20'] = [inc_30_20_m, inc_30_20_p]
inc['inc_30_p30'] = [inc_30_30_m, inc_30_30_p]
inc['inc_30_p40'] = [inc_30_40_m, inc_30_40_p]
inc['inc_30_p50'] = [inc_30_50_m, inc_30_50_p]
inc['inc_30_p60'] = [inc_30_60_m, inc_30_60_p]
inc['inc_30_p70'] = [inc_30_70_m, inc_30_70_p]
inc['inc_30_p80'] = [inc_30_80_m, inc_30_80_p]
inc['inc_30_p90'] = [inc_30_90_m, inc_30_90_p]

# %%
dep ={}

dep['dep_20_p10'] = [dep_20_10_m, dep_20_10_p]
dep['dep_20_p20'] = [dep_20_20_m, dep_20_20_p]
dep['dep_20_p30'] = [dep_20_30_m, dep_20_30_p]
dep['dep_20_p40'] = [dep_20_40_m, dep_20_40_p]
dep['dep_20_p50'] = [dep_20_50_m, dep_20_50_p]
dep['dep_20_p60'] = [dep_20_60_m, dep_20_60_p]
dep['dep_20_p70'] = [dep_20_70_m, dep_20_70_p]
dep['dep_20_p80'] = [dep_20_80_m, dep_20_80_p]
dep['dep_20_p90'] = [dep_20_90_m, dep_20_90_p]

dep['dep_25_p10'] = [dep_25_10_m, dep_25_10_p]
dep['dep_25_p20'] = [dep_25_20_m, dep_25_20_p]
dep['dep_25_p30'] = [dep_25_30_m, dep_25_30_p]
dep['dep_25_p40'] = [dep_25_40_m, dep_25_40_p]
dep['dep_25_p50'] = [dep_25_50_m, dep_25_50_p]
dep['dep_25_p60'] = [dep_25_60_m, dep_25_60_p]
dep['dep_25_p70'] = [dep_25_70_m, dep_25_70_p]
dep['dep_25_p80'] = [dep_25_80_m, dep_25_80_p]
dep['dep_25_p90'] = [dep_25_90_m, dep_25_90_p]

dep['dep_30_p10'] = [dep_30_10_m, dep_30_10_p]
dep['dep_30_p20'] = [dep_30_20_m, dep_30_20_p]
dep['dep_30_p30'] = [dep_30_30_m, dep_30_30_p]
dep['dep_30_p40'] = [dep_30_40_m, dep_30_40_p]
dep['dep_30_p50'] = [dep_30_50_m, dep_30_50_p]
dep['dep_30_p60'] = [dep_30_60_m, dep_30_60_p]
dep['dep_30_p70'] = [dep_30_70_m, dep_30_70_p]
dep['dep_30_p80'] = [dep_30_80_m, dep_30_80_p]
dep['dep_30_p90'] = [dep_30_90_m, dep_30_90_p]

# %%
beq =pd.DataFrame(beq, index = ['minimum', 'proper'])
inc =pd.DataFrame(inc, index = ['minimum', 'proper'])
dep =pd.DataFrame(dep, index = ['minimum', 'proper'])

# %%
beq.to_pickle(path + 'bequest.pkl')
inc.to_pickle(path + 'income.pkl')
dep.to_pickle(path + 'depletion.pkl')
